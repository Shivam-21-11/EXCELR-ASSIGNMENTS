# %% [markdown]
# # Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,10)
plt.rcParams['figure.dpi'] = 500
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.ensemble import RandomForestRegressor 
from sklearn import tree
from sklearn.metrics import classification_report , confusion_matrix
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (10,5)

# %% [markdown]
# # Data

# %%
df = pd.read_csv('./Company_Data.csv')
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age
# 0     9.50        138      73           11         276    120       Bad   42  \
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df=pd.get_dummies(df,columns=['ShelveLoc','Urban','US'], drop_first=True)

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education
# 0     9.50        138      73           11         276    120   42         17  \
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#      ShelveLoc_Good  ShelveLoc_Medium  Urban_Yes  US_Yes
# 0             False             False       True    True
# 1              True             False       True    True
# 2             False              True       True    True
# 3             False              True       True    True
# 4             False             False       True   False
# ..              ...               ...        ...     ...
# 395            True             False       True    True
# 396           False              True      False    True
# 397           False              True       True    True
# 398           False             False       True    True
# 399            True             False       True    True
#
# [400 rows x 12 columns]

# %% [markdown]
# # Viz

# %%
sns.scatterplot(x=df['Age'],y=df['Sales'])
# Out:
# <Axes: xlabel='Age', ylabel='Sales'>

# %%
sns.scatterplot(x=df['CompPrice'],y=df['Sales'])
# Out:
# <Axes: xlabel='CompPrice', ylabel='Sales'>

# %%
sns.scatterplot(x=df['Population'],y=df['Sales'])
# Out:
# <Axes: xlabel='Population', ylabel='Sales'>

# %%
sns.countplot(data=df,x='Urban_Yes',width=0.2)
# Out:
# <Axes: xlabel='Urban_Yes', ylabel='count'>

# %%
sns.countplot(data=df,x='US_Yes',width=0.2)
# Out:
# <Axes: xlabel='US_Yes', ylabel='count'>

# %% [markdown]
# # Random Forest

# %%
# split the feature and target
X = df.drop('Sales',axis=1)
Y = df['Sales']

# %%
# split train test 
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.1,random_state=42)

# %%
rf_reg = RandomForestRegressor().fit(xtrain,ytrain)

# %%
print('Training accuracy: ', rf_reg.score(xtrain,ytrain))
print('Testing Accuracy: ', rf_reg.score(xtest,ytest))
# Out:
# Training accuracy:  0.9569863454457608
# Testing Accuracy:  0.7318203519340967

# %% [markdown]
# # Hyperparameter

# %%
params = {'n_estimators':[100,150,300,200,500],
    'criterion' : ['squared_error', 'absolute_error','friedman_mse'],
    'max_depth' : [10,15,25,35],
}
grid = GridSearchCV(RandomForestRegressor(),params,verbose=1).fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits

# %%
grid.best_score_ , grid.best_params_
# Out:
# (0.6730353466037045,
#  {'criterion': 'friedman_mse', 'max_depth': 15, 'n_estimators': 500})

# %%
grid.best_estimator_.score(xtest,ytest)
# Out:
# 0.7356097661446181

# %%
grid.best_estimator_.score(xtrain,ytrain)
# Out:
# 0.9578143023137575

# %%
## Final model
rf_reg = RandomForestRegressor(n_estimators=500,criterion='friedman_mse',max_depth=15).fit(xtrain,ytrain)

# %% [markdown]
# # Feature Importance

# %%
rf_reg.feature_importances_
# Out:
# array([0.09515134, 0.0550049 , 0.08377938, 0.03858691, 0.30250036,
#        0.10247086, 0.02970845, 0.22927898, 0.05179736, 0.00573466,
#        0.0059868 ])

# %%
feature_df = pd.DataFrame({'Feature':X.columns,
                          'Importance':rf_reg.feature_importances_})
feature_df.sort_values('Importance',ascending=False,inplace=True)

# %%
feature_df
# Out:
#              Feature  Importance
# 4              Price    0.302500
# 7     ShelveLoc_Good    0.229279
# 5                Age    0.102471
# 0          CompPrice    0.095151
# 2        Advertising    0.083779
# 1             Income    0.055005
# 8   ShelveLoc_Medium    0.051797
# 3         Population    0.038587
# 6          Education    0.029708
# 10            US_Yes    0.005987
# 9          Urban_Yes    0.005735

# %%
sns.barplot(data=feature_df,y='Feature',x='Importance',palette='rainbow')
# Out:
# <Axes: xlabel='Importance', ylabel='Feature'>

# %% [markdown]
# *Observation :*
# * *Price has the highest importance.*
# * *Top 3 features that affect sales are Price , ShelveLoc_Good and Age*
