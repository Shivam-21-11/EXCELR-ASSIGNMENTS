# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf , plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf,pacf , adfuller
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
sns.set_theme(style='darkgrid',palette='rainbow')
plt.rcParams['figure.figsize'] = (10,5)

# %% [markdown]
# # Data

# %%
df = pd.read_excel('./CocaCola_Sales_Rawdata.xlsx',index_col=0)
df
# Out:
#                Sales
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996
# Q2_87    2104.411995
# Q3_87    2014.362999
# Q4_87    1991.746998
# Q1_88    1869.049999
# Q2_88    2313.631996
# Q3_88    2128.320000
# Q4_88    2026.828999
# Q1_89    1910.603996
# Q2_89    2331.164993
# Q3_89    2206.549995
# Q4_89    2173.967995
# Q1_90    2148.278000
# Q2_90    2739.307999
# Q3_90    2792.753998
# Q4_90    2556.009995
# Q1_91    2480.973999
# Q2_91    3039.522995
# Q3_91    3172.115997
# Q4_91    2879.000999
# Q1_92    2772.000000
# Q2_92    3550.000000
# Q3_92    3508.000000
# Q4_92    3243.859993
# Q1_93    3056.000000
# Q2_93    3899.000000
# Q3_93    3629.000000
# Q4_93    3373.000000
# Q1_94    3352.000000
# Q2_94    4342.000000
# Q3_94    4461.000000
# Q4_94    4017.000000
# Q1_95    3854.000000
# Q2_95    4936.000000
# Q3_95    4895.000000
# Q4_95    4333.000000
# Q1_96    4194.000000
# Q2_96    5253.000000

# %% [markdown]
# # EDA / VISUALIZATION / DATA PREPROCESSING

# %%
plt.plot(df.index,df['Sales'].values)
plt.title('Trend-Plot')
plt.xticks(rotation=90)
plt.show()

# %%
adf = adfuller(df['Sales'])
adf[1]
# Out:
# 0.9966611673930905

# %% [markdown]
# **Observation :**<br>
# *We can clearly see that there is upward trend and Additive seasonality.*

# %% [markdown]
# **ARIMA Models can only work with stationary data.**
#
# **To make out data stationary we do something like differencing.**

# %%
# Differencing
df['First Order'] = df['Sales'].diff()
df
# Out:
#                Sales  First Order
# Quarter
# Q1_86    1734.827000          NaN
# Q2_86    2244.960999   510.133999
# Q3_86    2533.804993   288.843994
# Q4_86    2154.962997  -378.841995
# Q1_87    1547.818996  -607.144001
# Q2_87    2104.411995   556.592999
# Q3_87    2014.362999   -90.048996
# Q4_87    1991.746998   -22.616001
# Q1_88    1869.049999  -122.696999
# Q2_88    2313.631996   444.581997
# Q3_88    2128.320000  -185.311996
# Q4_88    2026.828999  -101.491001
# Q1_89    1910.603996  -116.225002
# Q2_89    2331.164993   420.560997
# Q3_89    2206.549995  -124.614998
# Q4_89    2173.967995   -32.582001
# Q1_90    2148.278000   -25.689995
# Q2_90    2739.307999   591.029999
# Q3_90    2792.753998    53.445999
# Q4_90    2556.009995  -236.744003
# Q1_91    2480.973999   -75.035995
# Q2_91    3039.522995   558.548996
# Q3_91    3172.115997   132.593002
# Q4_91    2879.000999  -293.114998
# Q1_92    2772.000000  -107.000999
# Q2_92    3550.000000   778.000000
# Q3_92    3508.000000   -42.000000
# Q4_92    3243.859993  -264.140007
# Q1_93    3056.000000  -187.859993
# Q2_93    3899.000000   843.000000
# Q3_93    3629.000000  -270.000000
# Q4_93    3373.000000  -256.000000
# Q1_94    3352.000000   -21.000000
# Q2_94    4342.000000   990.000000
# Q3_94    4461.000000   119.000000
# Q4_94    4017.000000  -444.000000
# Q1_95    3854.000000  -163.000000
# Q2_95    4936.000000  1082.000000
# Q3_95    4895.000000   -41.000000
# Q4_95    4333.000000  -562.000000
# Q1_96    4194.000000  -139.000000
# Q2_96    5253.000000  1059.000000

# %%
plt.plot(df.index[1:],df['First Order'][1:].values)
plt.title('Trend-Plot')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observation :**<br>
# *We can observe that we can see seasonality but not trend.*

# %%
# Differencing
df['Second Order'] = df['First Order'].diff()
df
# Out:
#                Sales  First Order  Second Order
# Quarter
# Q1_86    1734.827000          NaN           NaN
# Q2_86    2244.960999   510.133999           NaN
# Q3_86    2533.804993   288.843994   -221.290005
# Q4_86    2154.962997  -378.841995   -667.685989
# Q1_87    1547.818996  -607.144001   -228.302006
# Q2_87    2104.411995   556.592999   1163.737000
# Q3_87    2014.362999   -90.048996   -646.641994
# Q4_87    1991.746998   -22.616001     67.432995
# Q1_88    1869.049999  -122.696999   -100.080997
# Q2_88    2313.631996   444.581997    567.278996
# Q3_88    2128.320000  -185.311996   -629.893993
# Q4_88    2026.828999  -101.491001     83.820995
# Q1_89    1910.603996  -116.225002    -14.734001
# Q2_89    2331.164993   420.560997    536.785999
# Q3_89    2206.549995  -124.614998   -545.175995
# Q4_89    2173.967995   -32.582001     92.032997
# Q1_90    2148.278000   -25.689995      6.892006
# Q2_90    2739.307999   591.029999    616.719994
# Q3_90    2792.753998    53.445999   -537.584000
# Q4_90    2556.009995  -236.744003   -290.190002
# Q1_91    2480.973999   -75.035995    161.708008
# Q2_91    3039.522995   558.548996    633.584991
# Q3_91    3172.115997   132.593002   -425.955994
# Q4_91    2879.000999  -293.114998   -425.708000
# Q1_92    2772.000000  -107.000999    186.113998
# Q2_92    3550.000000   778.000000    885.000999
# Q3_92    3508.000000   -42.000000   -820.000000
# Q4_92    3243.859993  -264.140007   -222.140007
# Q1_93    3056.000000  -187.859993     76.280014
# Q2_93    3899.000000   843.000000   1030.859993
# Q3_93    3629.000000  -270.000000  -1113.000000
# Q4_93    3373.000000  -256.000000     14.000000
# Q1_94    3352.000000   -21.000000    235.000000
# Q2_94    4342.000000   990.000000   1011.000000
# Q3_94    4461.000000   119.000000   -871.000000
# Q4_94    4017.000000  -444.000000   -563.000000
# Q1_95    3854.000000  -163.000000    281.000000
# Q2_95    4936.000000  1082.000000   1245.000000
# Q3_95    4895.000000   -41.000000  -1123.000000
# Q4_95    4333.000000  -562.000000   -521.000000
# Q1_96    4194.000000  -139.000000    423.000000
# Q2_96    5253.000000  1059.000000   1198.000000

# %%
plt.plot(df.index[2:],df['Second Order'][2:].values)
plt.title('Trend-Plot')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## ACF & PACF

# %%
## ACF
acfs = acf(df['First Order'][1:],nlags=45)
acfs
# Out:
# array([ 1.00000000e+00, -1.26981419e-01, -5.82481165e-01, -1.40789027e-01,
#         7.71496140e-01, -1.45527970e-01, -4.52000935e-01, -8.72084762e-02,
#         6.39895181e-01, -1.05905531e-01, -3.69200888e-01, -9.07728562e-02,
#         5.36613287e-01, -1.36535011e-01, -3.43810793e-01, -4.09638449e-02,
#         4.80234070e-01, -1.04610619e-01, -2.87942939e-01, -3.55019940e-02,
#         3.97481661e-01, -1.13063531e-01, -2.22754444e-01, -4.28279299e-02,
#         3.31747591e-01, -1.04697233e-01, -1.48255628e-01, -1.94271498e-02,
#         2.49826780e-01, -1.17787096e-01, -1.64872305e-01,  2.58490870e-04,
#         2.32847926e-01, -1.04459665e-01, -1.34616190e-01,  4.31712153e-02,
#         1.72921616e-01, -9.95491665e-02, -1.01851323e-01,  1.34708151e-02,
#         5.44303555e-02])

# %%
plot_acf(df['First Order'][1:],lags=18);

# %% [markdown]
# **Observation :**<br>
# *Significant change over the interval of 4 lags variable*

# %%
# PACF
pacfs = pacf(df['First Order'][1:],nlags=18)
pacfs
# Out:
# array([ 1.        , -0.13015595, -0.64013685, -0.6306896 ,  0.58559493,
#        -0.39750543,  0.1046144 , -0.0772609 ,  0.18417045,  0.20544454,
#        -0.00904403,  0.06302475,  0.30259239, -0.48114516, -0.13134357,
#         0.0170421 , -0.28961627,  0.40252766, -0.28543162])

# %%
plot_pacf(df['First Order'][1:],lags=18);

# %% [markdown]
# **Observation :**<br>
# *We can see direct correlation with 4 lags variable.*

# %%
# Second order 
acfs_2 = acf(df['Second Order'][2:],nlags=18)
acfs_2
# Out:
# array([ 1.        , -0.23982225, -0.38267713, -0.24983537,  0.7693965 ,
#        -0.19705087, -0.30335389, -0.2041167 ,  0.63118368, -0.15116405,
#        -0.24531228, -0.16457556,  0.53539212, -0.14415283, -0.24016991,
#        -0.11764592,  0.45886144, -0.12262558, -0.18818365])

# %%
plot_acf(df['Second Order'][2:],lags=18);

# %%
# PACF
pacfs_2 = pacf(df['Second Order'][2:],nlags=18)
pacfs_2
# Out:
# array([ 1.        , -0.24597154, -0.49315701, -0.75855567,  0.5206846 ,
#        -0.23167317, -0.10108477, -0.09022192,  0.07540586, -0.02038798,
#        -0.02911506,  0.0304781 ,  0.24231446, -0.07145356, -0.23352189,
#         0.03834016,  0.06070294, -0.09822948,  0.14115306])

# %%
plot_pacf(df['Second Order'][2:],lags=18);

# %% [markdown]
# # Model & Prediction

# %%
to_row = int(len(df)*0.8) + 1
train = df.iloc[:to_row]
test = df.iloc[to_row:]

# %% [markdown]
# ## Model Using Intitution

# %%
n_forecast = len(test)
train_list = list(train['Sales'].values)
preds = []
for i in tqdm(range(n_forecast)):
    model = ARIMA(train_list,order=(4,1,1))
    model = model.fit()
    forecast = model.forecast()
    preds.append(forecast[0])
    train_list.pop(0)
    train_list.append(forecast[0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00,  8.02it/s]

# %%
plt.plot(test.index,test['Sales'].values,color='red',label='test')
plt.plot(test.index,preds,color='green',label='pred')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
mse = np.sqrt(mean_squared_error(test['Sales'].values,preds))
mse
# Out:
# 436.37108461466926

# %% [markdown]
# ## Auto Arima

# %%
from pmdarima import auto_arima

# %%
order = auto_arima(df['Sales'])
order
# Out:
# ARIMA(order=(4, 1, 0), scoring_args={}, suppress_warnings=True)

# %%
n_forecast = len(test)
train_list = list(train['Sales'].values)
preds = []
for i in tqdm(range(n_forecast)):
    model = ARIMA(train_list,order=(4,1,0))
    model = model.fit()
    forecast = model.forecast()
    preds.append(forecast[0])
    train_list.pop(0)
    train_list.append(forecast[0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.98it/s]

# %%
plt.plot(test.index,test['Sales'].values,color='red',label='test')
plt.plot(test.index,preds,color='green',label='pred')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
mse2 = np.sqrt(mean_squared_error(test['Sales'].values,preds))
mse2
# Out:
# 438.7308555087816

# %% [markdown]
# ## Experimental Model

# %%
n_forecast = len(test)
train_list = list(train['Sales'].values)
preds = []
for i in tqdm(range(n_forecast)):
    model = ARIMA(train_list,order=(4,1,6))
    model = model.fit()
    forecast = model.forecast()
    preds.append(forecast[0])
    train_list.pop(0)
    train_list.append(forecast[0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  4.15it/s]

# %%
plt.plot(test.index,test['Sales'].values,color='red',label='test')
plt.plot(test.index,preds,color='green',label='pred')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
mse3 = np.sqrt(mean_squared_error(test['Sales'].values,preds))
mse3
# Out:
# 363.86721754253915

# %%
out_data = {
    'Model': ['Intitution Model','Auto Arima Model','Experimental Model'],
    'Lag Variable': [4,4,4],
    'Order': [(4,1,1),(4,1,0),(4,1,6)],
    'MSE': [mse,mse2,mse3]
}

pd.DataFrame(out_data)
# Out:
#                 Model  Lag Variable      Order         MSE
# 0    Intitution Model             4  (4, 1, 1)  436.371085
# 1    Auto Arima Model             4  (4, 1, 0)  438.730856
# 2  Experimental Model             4  (4, 1, 6)  363.867218
