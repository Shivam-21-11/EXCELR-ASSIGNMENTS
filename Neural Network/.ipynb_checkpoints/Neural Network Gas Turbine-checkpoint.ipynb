# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np 
import tensorflow as tf
from tensorflow.keras.models import Model ,Sequential
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
sns.set_theme(style='darkgrid',palette='rainbow')
plt.rcParams['figure.figsize'] = (15,10)

# %% [markdown]
# # Data

# %%
df = pd.read_csv('./gas_turbines.csv')
df
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605  \
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
# I create attribute information dataframe
atrr = pd.read_csv('./gas_turbine_data.csv',index_col=1)
atrr
# Out:
#                             Variable   Unit      Min      Max     Mean
# Abbr
# AT               Ambient temperature      C     6.23    37.10    17.71
# AP                  Ambient pressure   mbar   985.85  1036.56  1013.07
# AH                  Ambient humidity    (%)    24.08   100.20    77.87
# AFDP  Air filter difference pressure   mbar     2.09     7.61     3.93
# GTEP    Gas turbine exhaust pressure   mbar    17.70    40.72    25.56
# TIT        Turbine inlet temperature      C  1000.85  1100.89  1081.43
# TAT        Turbine after temperature      C   511.04   550.61   546.16
# CDP    Compressor discharge pressure   mbar     9.85    15.16    12.06
# TEY             Turbine energy yield    MWH   100.02   179.50   133.51
# CO                   Carbon monoxide  mg/m3     0.00    44.10     2.37
# NOX                  Nitrogen oxides  mg/m3    25.90   119.91    65.29

# %% [markdown]
# # EDA

# %% [markdown]
# ## check for null and duplicate

# %%
df.isna().any()
# Out:
# AT      False
# AP      False
# AH      False
# AFDP    False
# GTEP    False
# TIT     False
# TAT     False
# TEY     False
# CDP     False
# CO      False
# NOX     False
# dtype: bool

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [AT, AP, AH, AFDP, GTEP, TIT, TAT, TEY, CDP, CO, NOX]
# Index: []

# %% [markdown]
# **No Null or duplicated fields**

# %% [markdown]
# ## Statistical inference

# %% [markdown]
# *For our problem statement the variable TEY is our target*

# %%
df.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000  \
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000  \
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
# Correlation plot
sns.heatmap(df.corr(),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# *Many variables are highly positively correlated to our target column*

# %% [markdown]
# ## Viz

# %%
sns.regplot(x='AFDP', y='TEY', data=df,line_kws={'color':'red','label':'Best Fit Line'})
plt.legend()

# %%
sns.regplot(x='GTEP', y='TEY', data=df,line_kws={'color':'red','label':'Best Fit Line'})
plt.legend()

# %%
sns.regplot(x='TIT', y='TEY', data=df,line_kws={'color':'red','label':'Best Fit Line'})
plt.legend()

# %%
sns.regplot(x='CDP', y='TEY', data=df,line_kws={'color':'red','label':'Best Fit Line'})
plt.legend()

# %%
sns.regplot(x='CO', y='TEY', data=df,line_kws={'color':'red','label':'Best Fit Line'})
plt.legend()

# %% [markdown]
# *These are some of the highly correlated variables*

# %%
sns.boxplot(df[['AT','AP','AH','AFDP','GTEP','TIT','TAT','CDP','CO','NOX']])
# Out:
# <Axes: >

# %%
clf = ['AT','AP','AH','AFDP','GTEP','TIT','TAT','CDP','CO','NOX']
for i in clf:
    min_val = round(atrr.loc[i,'Min'],2)
    max_val = round(atrr.loc[i,'Max'],2)
    print(f"For Column {i} there are : \n {len(df[df[i]>max_val])} values that are greater than max value : {max_val} \n\
    {len(df[df[i]<min_val])} values that are less than min value : {min_val} \n")
# Out:
# For Column AT there are :
#  0 values that are greater than max value : 37.1
#     980 values that are less than min value : 6.23
#
# For Column AP there are :
#  0 values that are greater than max value : 1036.56
#     0 values that are less than min value : 985.85
#
# For Column AH there are :
#  0 values that are greater than max value : 100.2
#     0 values that are less than min value : 24.08
#
# For Column AFDP there are :
#  1 values that are greater than max value : 7.61
#     1 values that are less than min value : 2.09
#
# For Column GTEP there are :
#  0 values that are greater than max value : 40.72
#     0 values that are less than min value : 17.7
#
# For Column TIT there are :
#  0 values that are greater than max value : 1100.89
#     1 values that are less than min value : 1000.85
#
# For Column TAT there are :
#  0 values that are greater than max value : 550.61
#     0 values that are less than min value : 511.04
#
# For Column CDP there are :
#  0 values that are greater than max value : 15.16
#     0 values that are less than min value : 9.85
#
# For Column CO there are :
#  1 values that are greater than max value : 44.1
#     0 values that are less than min value : 0.0
#
# For Column NOX there are :
#  0 values that are greater than max value : 119.91
#     0 values that are less than min value : 25.9

# %% [markdown]
# *These are the outliers according to out attribute information given in the problem statement*

# %%
df.drop(index=df[df['AT']<6.23].index,inplace=True)

# %% [markdown]
# # DataPreprocessing

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X = df.drop('TEY',axis=1)
Y = df['TEY']

# %%
std = StandardScaler()
scaled = std.fit_transform(X)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(scaled,Y,test_size=0.2,random_state=42)

# %% [markdown]
# # Model

# %% [markdown]
# ## Base model

# %% [markdown]
# *A simple 2 layer dense network is capable of modeling any linear relation so we are going to use this as baseline model*

# %%
x_in = tf.keras.Input(shape=(10))
x = tf.keras.layers.Dense(16,activation='relu')(x_in)
x = tf.keras.layers.Dense(1)(x)
model = Model(inputs=[x_in],outputs=[x])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense (Dense)               (None, 16)                176
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
model.compile(optimizer=tf.keras.optimizers.Adam(),
             loss=tf.keras.losses.MSE)

# %%
history = model.fit(xtrain,ytrain,batch_size=8,epochs=50,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 1406/1406 [==============================] - 7s 4ms/step - loss: 12980.7744 - val_loss: 6013.9424
# Epoch 2/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 2263.5486 - val_loss: 629.8058
# Epoch 3/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 353.8483 - val_loss: 230.6458
# Epoch 4/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 181.1458 - val_loss: 141.9136
# Epoch 5/50
# 1406/1406 [==============================] - 6s 5ms/step - loss: 114.3136 - val_loss: 91.7097
# Epoch 6/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 75.7702 - val_loss: 62.7372
# Epoch 7/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 52.6724 - val_loss: 45.2938
# Epoch 8/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 38.1754 - val_loss: 32.5344
# Epoch 9/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 26.7704 - val_loss: 22.3830
# Epoch 10/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 17.9262 - val_loss: 14.4659
# Epoch 11/50
# 1406/1406 [==============================] - 6s 5ms/step - loss: 11.7669 - val_loss: 10.2618
# Epoch 12/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 7.9348 - val_loss: 6.4943
# Epoch 13/50
# 1406/1406 [==============================] - 6s 5ms/step - loss: 5.3416 - val_loss: 4.7348
# Epoch 14/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 3.7201 - val_loss: 3.4085
# Epoch 15/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 2.6864 - val_loss: 2.4277
# Epoch 16/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 2.0311 - val_loss: 1.8977
# Epoch 17/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 1.6360 - val_loss: 1.5852
# Epoch 18/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 1.3349 - val_loss: 1.2549
# Epoch 19/50
# 1406/1406 [==============================] - 7s 5ms/step - loss: 1.1353 - val_loss: 1.0843
# Epoch 20/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.9583 - val_loss: 1.0726
# Epoch 21/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.8372 - val_loss: 0.8389
# Epoch 22/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.7678 - val_loss: 0.7853
# Epoch 23/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.7105 - val_loss: 0.7078
# Epoch 24/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.6717 - val_loss: 0.6490
# Epoch 25/50
# 1406/1406 [==============================] - 6s 5ms/step - loss: 0.6275 - val_loss: 0.6631
# Epoch 26/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.5804 - val_loss: 0.6119
# Epoch 27/50
# 1406/1406 [==============================] - 5s 3ms/step - loss: 0.5637 - val_loss: 0.5521
# Epoch 28/50
# 1406/1406 [==============================] - 5s 3ms/step - loss: 0.5402 - val_loss: 0.8054
# Epoch 29/50
# 1406/1406 [==============================] - 4s 3ms/step - loss: 0.5209 - val_loss: 0.5853
# Epoch 30/50
# 1406/1406 [==============================] - 5s 3ms/step - loss: 0.5063 - val_loss: 0.5115
# Epoch 31/50
# 1406/1406 [==============================] - 4s 3ms/step - loss: 0.4889 - val_loss: 0.4864
# Epoch 32/50
# 1406/1406 [==============================] - 4s 3ms/step - loss: 0.4834 - val_loss: 0.4817
# Epoch 33/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.4799 - val_loss: 0.4842
# Epoch 34/50
# 1406/1406 [==============================] - 7s 5ms/step - loss: 0.4724 - val_loss: 0.4831
# Epoch 35/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.4672 - val_loss: 0.4602
# Epoch 36/50
# 1406/1406 [==============================] - 7s 5ms/step - loss: 0.4570 - val_loss: 0.5051
# Epoch 37/50
# 1406/1406 [==============================] - 7s 5ms/step - loss: 0.4570 - val_loss: 0.4499
# Epoch 38/50
# 1406/1406 [==============================] - 6s 5ms/step - loss: 0.4593 - val_loss: 0.4306
# Epoch 39/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.4562 - val_loss: 0.4489
# Epoch 40/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4478 - val_loss: 0.4500
# Epoch 41/50
# 1406/1406 [==============================] - 5s 3ms/step - loss: 0.4493 - val_loss: 0.4799
# Epoch 42/50
# 1406/1406 [==============================] - 5s 3ms/step - loss: 0.4468 - val_loss: 0.4178
# Epoch 43/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.4408 - val_loss: 0.4626
# Epoch 44/50
# 1406/1406 [==============================] - 7s 5ms/step - loss: 0.4491 - val_loss: 0.4361
# Epoch 45/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4353 - val_loss: 0.4343
# Epoch 46/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4371 - val_loss: 0.4208
# Epoch 47/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4453 - val_loss: 0.5032
# Epoch 48/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.4386 - val_loss: 0.4420
# Epoch 49/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.4310 - val_loss: 0.4138
# Epoch 50/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4296 - val_loss: 0.4322

# %%
pd.DataFrame(history.history).plot(kind='line')
# Out:
# <Axes: >

# %%
r2_score(ytest,model.predict(xtest))
# Out:
# 88/88 [==============================] - 0s 1ms/step
# 0.9981670080642915

# %% [markdown]
# *The Baseline model already performs better but still i will show some methods to finetune the model*

# %% [markdown]
# # HyperParameter Tuning

# %%
import keras_tuner as kt

# %%
def hyper(hp):
    model = Sequential()
    counter = 0
    for i in range(hp.Int('num_layers',min_value = 1, max_value=10)):
        if counter == 0:
            model.add(tf.keras.layers.Dense(hp.Int('units'+str(i),min_value=8,max_value=128,step=8),
                           activation = hp.Choice('activation'+str(i),values=['relu','tanh','sigmoid']),
                           input_dim=10))
            counter = counter + 1
        else:
            model.add(tf.keras.layers.Dense(hp.Int('units'+str(i),min_value=8,max_value=128,step=8),
                           activation=hp.Choice('activation'+str(i),values=['relu','sigmoid','tanh'])))
    model.add(tf.keras.layers.Dense(1))
    model.compile(optimizer= hp.Choice('Optimizer',values=['adam','rmsprop','sgd']),
                     loss = tf.keras.losses.MSE)
    return model

# %%
tuner = kt.RandomSearch(hyper,
                       objective='val_loss',
                        overwrite=True,
                       max_trials=3
                       )
tuner.search(xtrain,ytrain,epochs = 10 , validation_data=(xtest,ytest))
# Out:
# Trial 3 Complete [00h 00m 24s]
# val_loss: 235.786376953125
#
# Best val_loss So Far: 0.5515536665916443
# Total elapsed time: 00h 01m 14s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.get_best_models()[0].summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                352
#
#  dense_1 (Dense)             (None, 8)                 264
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 697
# Trainable params: 697
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.momentum
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.rho

# %%
tf.keras.utils.plot_model(tuner.get_best_models()[0],show_layer_activations=True,show_shapes=True)
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.momentum
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.rho

# %% [markdown]
# ### Model with best score

# %%
x_in = tf.keras.layers.Input(shape=(10))
x = tf.keras.layers.Dense(40,activation='relu')(x_in)
x = tf.keras.layers.Dense(1,activation='linear')(x)
fmodel = Model(inputs=[x_in],outputs=[x])
fmodel.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense_4 (Dense)             (None, 40)                440
#
#  dense_5 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(fmodel,show_layer_activations=True,show_shapes=True)

# %%
fmodel.compile(optimizer=tf.keras.optimizers.Adam(),
             loss=tf.keras.losses.MSE)

# %%
history = fmodel.fit(xtrain,ytrain,batch_size=8,epochs=50,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 7241.2891 - val_loss: 709.5528
# Epoch 2/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 324.9637 - val_loss: 190.9063
# Epoch 3/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 140.7021 - val_loss: 101.6516
# Epoch 4/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 78.4348 - val_loss: 59.3714
# Epoch 5/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 45.5287 - val_loss: 35.6706
# Epoch 6/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 27.4862 - val_loss: 21.2980
# Epoch 7/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 15.7533 - val_loss: 10.9817
# Epoch 8/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 7.9505 - val_loss: 5.0770
# Epoch 9/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 3.8719 - val_loss: 2.7121
# Epoch 10/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 2.1210 - val_loss: 1.5625
# Epoch 11/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 1.3087 - val_loss: 1.0086
# Epoch 12/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.9191 - val_loss: 0.8257
# Epoch 13/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.7232 - val_loss: 0.7123
# Epoch 14/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.6166 - val_loss: 0.5342
# Epoch 15/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.5489 - val_loss: 0.6322
# Epoch 16/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.5017 - val_loss: 0.5253
# Epoch 17/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4990 - val_loss: 0.5250
# Epoch 18/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4609 - val_loss: 0.4164
# Epoch 19/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4400 - val_loss: 0.4761
# Epoch 20/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4350 - val_loss: 0.4296
# Epoch 21/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4385 - val_loss: 0.4974
# Epoch 22/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4334 - val_loss: 0.3855
# Epoch 23/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4183 - val_loss: 0.4398
# Epoch 24/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4163 - val_loss: 0.3684
# Epoch 25/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4042 - val_loss: 0.4152
# Epoch 26/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4143 - val_loss: 0.4295
# Epoch 27/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3996 - val_loss: 0.3738
# Epoch 28/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3909 - val_loss: 0.3905
# Epoch 29/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3955 - val_loss: 0.3723
# Epoch 30/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3986 - val_loss: 0.4077
# Epoch 31/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4019 - val_loss: 0.5086
# Epoch 32/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3819 - val_loss: 0.3929
# Epoch 33/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3811 - val_loss: 0.3535
# Epoch 34/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.4013 - val_loss: 0.4204
# Epoch 35/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3767 - val_loss: 0.3511
# Epoch 36/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3927 - val_loss: 0.3413
# Epoch 37/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3691 - val_loss: 0.3948
# Epoch 38/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3775 - val_loss: 0.4202
# Epoch 39/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3969 - val_loss: 0.3364
# Epoch 40/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3629 - val_loss: 0.3556
# Epoch 41/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3809 - val_loss: 0.3599
# Epoch 42/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3752 - val_loss: 0.3729
# Epoch 43/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.3693 - val_loss: 0.3403
# Epoch 44/50
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.3753 - val_loss: 0.4166
# Epoch 45/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3685 - val_loss: 0.3564
# Epoch 46/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3718 - val_loss: 0.4958
# Epoch 47/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3714 - val_loss: 0.4036
# Epoch 48/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3856 - val_loss: 0.3257
# Epoch 49/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3754 - val_loss: 0.3644
# Epoch 50/50
# 1406/1406 [==============================] - 5s 4ms/step - loss: 0.3738 - val_loss: 0.3592

# %%
pd.DataFrame(history.history).plot(kind='line')
# Out:
# <Axes: >

# %%
r2_score(ytest,fmodel.predict(xtest))
# Out:
# 88/88 [==============================] - 0s 1ms/step
# 0.9984767061070735
