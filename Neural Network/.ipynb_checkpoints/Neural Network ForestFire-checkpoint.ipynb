# %% [markdown]
# # Imports

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential , Model
from sklearn.metrics import classification_report , confusion_matrix
from tensorflow.keras.layers import Dense
sns.set_theme(style='darkgrid',palette='rainbow')
plt.rcParams['figure.figsize'] = (15,10)

# %% [markdown]
# # Data

# %%
df = pd.read_csv('./forestfires.csv')
df
# Out:
#     month  day  FFMC    DMC     DC   ISI  ...  monthmar  monthmay  monthnov  monthoct  monthsep  size_category
# 0     mar  fri  86.2   26.2   94.3   5.1  ...         1         0         0         0         0          small
# 1     oct  tue  90.6   35.4  669.1   6.7  ...         0         0         0         1         0          small
# 2     oct  sat  90.6   43.7  686.9   6.7  ...         0         0         0         1         0          small
# 3     mar  fri  91.7   33.3   77.5   9.0  ...         1         0         0         0         0          small
# 4     mar  sun  89.3   51.3  102.2   9.6  ...         1         0         0         0         0          small
# ..    ...  ...   ...    ...    ...   ...  ...       ...       ...       ...       ...       ...            ...
# 512   aug  sun  81.6   56.7  665.6   1.9  ...         0         0         0         0         0          large
# 513   aug  sun  81.6   56.7  665.6   1.9  ...         0         0         0         0         0          large
# 514   aug  sun  81.6   56.7  665.6   1.9  ...         0         0         0         0         0          large
# 515   aug  sat  94.4  146.0  614.7  11.3  ...         0         0         0         0         0          small
# 516   nov  tue  79.5    3.0  106.7   1.1  ...         0         0         1         0         0          small
#
# [517 rows x 31 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## check for null and duplicates

# %%
df.isna().any()
# Out:
# month            False
# day              False
# FFMC             False
# DMC              False
# DC               False
# ISI              False
# temp             False
# RH               False
# wind             False
# rain             False
# area             False
# dayfri           False
# daymon           False
# daysat           False
# daysun           False
# daythu           False
# daytue           False
# daywed           False
# monthapr         False
# monthaug         False
# monthdec         False
# monthfeb         False
# monthjan         False
# monthjul         False
# monthjun         False
# monthmar         False
# monthmay         False
# monthnov         False
# monthoct         False
# monthsep         False
# size_category    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#     month  day  FFMC    DMC     DC   ISI  ...  monthmar  monthmay  monthnov  monthoct  monthsep  size_category
# 53    aug  wed  92.1  111.2  654.1   9.6  ...         0         0         0         0         0          small
# 100   aug  sun  91.4  142.4  601.4  10.6  ...         0         0         0         0         0          small
# 215   mar  sat  91.7   35.8   80.8   7.8  ...         1         0         0         0         0          large
# 303   jun  fri  91.1   94.1  232.1   7.1  ...         0         0         0         0         0          small
# 426   aug  thu  91.6  248.4  753.8   6.3  ...         0         0         0         0         0          small
# 461   aug  sat  93.7  231.1  715.1   8.4  ...         0         0         0         0         0          small
# 501   aug  tue  96.1  181.1  671.2  14.3  ...         0         0         0         0         0          small
# 508   aug  fri  91.0  166.9  752.6   7.1  ...         0         0         0         0         0          small
#
# [8 rows x 31 columns]

# %%
df.drop(index=list(df[df.duplicated()].index),inplace=True)

# %% [markdown]
# **Drop month and day feature since it is already one hot encoded**

# %%
df.drop(columns=['month','day'],inplace=True)

# %%
df.describe()
# Out:
#              FFMC         DMC          DC         ISI  ...    monthmay    monthnov    monthoct    monthsep
# count  509.000000  509.000000  509.000000  509.000000  ...  509.000000  509.000000  509.000000  509.000000
# mean    90.618075  110.235756  547.787623    9.023576  ...    0.003929    0.001965    0.029470    0.337917
# std      5.555527   63.804112  248.196222    4.585083  ...    0.062622    0.044324    0.169285    0.473466
# min     18.700000    1.100000    7.900000    0.000000  ...    0.000000    0.000000    0.000000    0.000000
# 25%     90.200000   62.300000  437.700000    6.400000  ...    0.000000    0.000000    0.000000    0.000000
# 50%     91.600000  108.300000  664.200000    8.400000  ...    0.000000    0.000000    0.000000    0.000000
# 75%     92.900000  141.300000  713.900000   11.000000  ...    0.000000    0.000000    0.000000    1.000000
# max     96.200000  291.300000  860.600000   56.100000  ...    1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# # Viz

# %%
sns.countplot(data=df,x='size_category',width=0.2)
# Out:
# <Axes: xlabel='size_category', ylabel='count'>

# %%
df.columns
# Out:
# Index(['FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area',
#        'dayfri', 'daymon', 'daysat', 'daysun', 'daythu', 'daytue', 'daywed',
#        'monthapr', 'monthaug', 'monthdec', 'monthfeb', 'monthjan', 'monthjul',
#        'monthjun', 'monthmar', 'monthmay', 'monthnov', 'monthoct', 'monthsep',
#        'size_category'],
#       dtype='object')

# %%
sns.pairplot(data=df[['FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area','size_category']],hue='size_category')

# %% [markdown]
# # DataPreprocessing

# %%
from sklearn.preprocessing import StandardScaler , LabelEncoder
from sklearn.model_selection import train_test_split

# %%
X = df.drop('size_category',axis=1)
Y = df['size_category']

# %%
lbenc = LabelEncoder()
Y = lbenc.fit_transform(Y)

# %%
std = StandardScaler()
scaled = std.fit_transform(X)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(scaled,Y,test_size=0.2,random_state=42)

# %% [markdown]
# # Model

# %%
def plot_history(hist):
    hist = hist.history
    acc = hist['accuracy']
    val_acc = hist['val_accuracy']
    loss = hist['loss']
    val_loss = hist['val_loss']
    epochs = len(acc)
    
    plt.subplot(1,2,1)
    plt.plot(range(epochs),loss,label='loss')
    plt.plot(range(epochs),val_loss,label='val_loss')
    plt.legend()
    plt.tight_layout()
    plt.subplot(1,2,2)
    plt.plot(range(epochs),acc,label='accuracy')
    plt.plot(range(epochs),val_acc,label='val_accuracy')
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# # Baseline Model

# %%
x_in = tf.keras.Input(shape=(28))
x = tf.keras.layers.Dense(16,activation='relu')(x_in)
x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
model = Model(inputs=[x_in],outputs=[x])
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28)]              0
#
#  dense_36 (Dense)            (None, 16)                464
#
#  dense_37 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
             loss=tf.keras.losses.BinaryCrossentropy(),
             metrics=['accuracy'])

# %%
history = model.fit(xtrain,ytrain,batch_size=16,epochs=50,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 26/26 [==============================] - 1s 16ms/step - loss: 1.3965 - accuracy: 0.2801 - val_loss: 1.2329 - val_accuracy: 0.3333
# Epoch 2/50
# 26/26 [==============================] - 0s 8ms/step - loss: 1.1880 - accuracy: 0.3219 - val_loss: 1.0738 - val_accuracy: 0.3725
# Epoch 3/50
# 26/26 [==============================] - 0s 7ms/step - loss: 1.0195 - accuracy: 0.3661 - val_loss: 0.9444 - val_accuracy: 0.4118
# Epoch 4/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.8881 - accuracy: 0.4595 - val_loss: 0.8516 - val_accuracy: 0.5000
# Epoch 5/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.7878 - accuracy: 0.5332 - val_loss: 0.7793 - val_accuracy: 0.5098
# Epoch 6/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.7130 - accuracy: 0.6143 - val_loss: 0.7291 - val_accuracy: 0.5098
# Epoch 7/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.6602 - accuracy: 0.6536 - val_loss: 0.6895 - val_accuracy: 0.5882
# Epoch 8/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.6203 - accuracy: 0.6978 - val_loss: 0.6626 - val_accuracy: 0.6078
# Epoch 9/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5929 - accuracy: 0.7371 - val_loss: 0.6436 - val_accuracy: 0.6667
# Epoch 10/50
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5740 - accuracy: 0.7543 - val_loss: 0.6282 - val_accuracy: 0.7157
# Epoch 11/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5551 - accuracy: 0.7592 - val_loss: 0.6192 - val_accuracy: 0.7353
# Epoch 12/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5421 - accuracy: 0.7592 - val_loss: 0.6114 - val_accuracy: 0.7451
# Epoch 13/50
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5319 - accuracy: 0.7641 - val_loss: 0.6039 - val_accuracy: 0.7745
# Epoch 14/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5226 - accuracy: 0.7690 - val_loss: 0.5991 - val_accuracy: 0.7647
# Epoch 15/50
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5151 - accuracy: 0.7690 - val_loss: 0.5950 - val_accuracy: 0.7647
# Epoch 16/50
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5084 - accuracy: 0.7715 - val_loss: 0.5906 - val_accuracy: 0.7745
# Epoch 17/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5013 - accuracy: 0.7740 - val_loss: 0.5880 - val_accuracy: 0.7745
# Epoch 18/50
# 26/26 [==============================] - 0s 6ms/step - loss: 0.4954 - accuracy: 0.7715 - val_loss: 0.5834 - val_accuracy: 0.7745
# Epoch 19/50
# 26/26 [==============================] - 0s 6ms/step - loss: 0.4893 - accuracy: 0.7764 - val_loss: 0.5802 - val_accuracy: 0.7745
# Epoch 20/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.4836 - accuracy: 0.7764 - val_loss: 0.5776 - val_accuracy: 0.7745
# Epoch 21/50
# 26/26 [==============================] - 0s 9ms/step - loss: 0.4780 - accuracy: 0.7789 - val_loss: 0.5745 - val_accuracy: 0.7745
# Epoch 22/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.4732 - accuracy: 0.7838 - val_loss: 0.5720 - val_accuracy: 0.7745
# Epoch 23/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.4683 - accuracy: 0.7862 - val_loss: 0.5685 - val_accuracy: 0.7745
# Epoch 24/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0
# 26/26 [==============================] - 0s 7ms/step - loss: 0.3508 - accuracy: 0.8428 - val_loss: 0.5205 - val_accuracy: 0.8039
# Epoch 50/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.3474 - accuracy: 0.8452 - val_loss: 0.5217 - val_accuracy: 0.7941

# %%
plot_history(history)

# %%
ypred = model.predict(xtest)
ypred = ypred > 0.5
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.38      0.51        29
#            1       0.80      0.96      0.87        73
#
#     accuracy                           0.79       102
#    macro avg       0.79      0.67      0.69       102
# weighted avg       0.79      0.79      0.77       102

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True)
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %% [markdown]
# # Hyperparameter tuning

# %%
import keras_tuner as kt

# %%
def hyper(hp):
    model = Sequential()
    counter = 0
    for i in range(hp.Int('num_layers',min_value = 1, max_value=10)):
        if counter == 0:
            model.add(Dense(hp.Int('units'+str(i),min_value=8,max_value=128,step=8),
                           activation = hp.Choice('activation'+str(i),values=['relu','tanh','sigmoid']),
                           input_dim=28))
            counter = counter + 1
        else:
            model.add(Dense(hp.Int('units'+str(i),min_value=8,max_value=128,step=8),
                           activation=hp.Choice('activation'+str(i),values=['relu','sigmoid','tanh'])))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(optimizer= hp.Choice('Optimizer',values=['adam','rmsprop','sgd']),
                     loss = 'binary_crossentropy',metrics = 'accuracy')
    return model

# %%
tuner = kt.RandomSearch(hyper,
                       objective='val_accuracy',
                        overwrite=True,
                       max_trials=5
                       )
tuner.search(xtrain,ytrain,epochs = 10 , validation_data=(xtest,ytest))
# Out:
# Trial 5 Complete [00h 00m 06s]
# val_accuracy: 0.7156862616539001
#
# Best val_accuracy So Far: 0.7941176295280457
# Total elapsed time: 00h 00m 32s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.get_best_models()[0].summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               3712
#
#  dense_1 (Dense)             (None, 8)                 1032
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 8)                 72
#
#  dense_4 (Dense)             (None, 8)                 72
#
#  dense_5 (Dense)             (None, 8)                 72
#
#  dense_6 (Dense)             (None, 8)                 72
#
#  dense_7 (Dense)             (None, 8)                 72
#
#  dense_8 (Dense)             (None, 8)                 72
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 5,257
# Trainable params: 5,257
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate

# %%
tf.keras.utils.plot_model(tuner.get_best_models()[0],show_layer_activations=True,show_shapes=True)
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate

# %% [markdown]
# # final model

# %%
x_in = tf.keras.layers.Input(shape=(28))
x = tf.keras.layers.Dense(104,activation='tanh')(x_in)
x = tf.keras.layers.Dense(24,activation='tanh')(x)
x = tf.keras.layers.Dense(40,activation='tanh')(x)
x = tf.keras.layers.Dense(40,activation='relu')(x)
x = tf.keras.layers.Dense(40,activation='sigmoid')(x)
x = tf.keras.layers.Dense(8,activation='relu')(x)
x = tf.keras.layers.Dense(8,activation='relu')(x)
x = tf.keras.layers.Dense(8,activation='relu')(x)
x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
fmodel = Model(inputs=[x_in],outputs=[x])
fmodel.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28)]              0
#
#  dense_10 (Dense)            (None, 104)               3016
#
#  dense_11 (Dense)            (None, 24)                2520
#
#  dense_12 (Dense)            (None, 40)                1000
#
#  dense_13 (Dense)            (None, 40)                1640
#
#  dense_14 (Dense)            (None, 40)                1640
#
#  dense_15 (Dense)            (None, 8)                 328
#
#  dense_16 (Dense)            (None, 8)                 72
#
#  dense_17 (Dense)            (None, 8)                 72
#
#  dense_18 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 10,297
# Trainable params: 10,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(fmodel,show_shapes=True,show_layer_activations=True)

# %%
fmodel.compile(optimizer=tf.keras.optimizers.Adam(),
             loss=tf.keras.losses.BinaryCrossentropy(),
             metrics=['accuracy'])

# %%
history = fmodel.fit(xtrain,ytrain,batch_size=16,epochs=50,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 26/26 [==============================] - 1s 21ms/step - loss: 0.6004 - accuracy: 0.7322 - val_loss: 0.5915 - val_accuracy: 0.7157
# Epoch 2/50
# 26/26 [==============================] - 0s 9ms/step - loss: 0.5695 - accuracy: 0.7322 - val_loss: 0.5790 - val_accuracy: 0.7157
# Epoch 3/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.5453 - accuracy: 0.7322 - val_loss: 0.5663 - val_accuracy: 0.7157
# Epoch 4/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.5026 - accuracy: 0.7420 - val_loss: 0.5485 - val_accuracy: 0.8039
# Epoch 5/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.4178 - accuracy: 0.8354 - val_loss: 0.5061 - val_accuracy: 0.8039
# Epoch 6/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.3205 - accuracy: 0.8968 - val_loss: 0.4376 - val_accuracy: 0.8333
# Epoch 7/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.2451 - accuracy: 0.9115 - val_loss: 0.3550 - val_accuracy: 0.8627
# Epoch 8/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1816 - accuracy: 0.9410 - val_loss: 0.3950 - val_accuracy: 0.8725
# Epoch 9/50
# 26/26 [==============================] - 0s 12ms/step - loss: 0.1365 - accuracy: 0.9558 - val_loss: 0.4104 - val_accuracy: 0.8431
# Epoch 10/50
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1220 - accuracy: 0.9533 - val_loss: 0.4870 - val_accuracy: 0.8627
# Epoch 11/50
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1279 - accuracy: 0.9558 - val_loss: 0.3694 - val_accuracy: 0.8529
# Epoch 12/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0653 - accuracy: 0.9705 - val_loss: 0.4551 - val_accuracy: 0.8922
# Epoch 13/50
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0382 - accuracy: 0.9853 - val_loss: 0.4139 - val_accuracy: 0.8922
# Epoch 14/50
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0830 - accuracy: 0.9607 - val_loss: 0.5870 - val_accuracy: 0.8627
# Epoch 15/50
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0764 - accuracy: 0.9705 - val_loss: 0.4009 - val_accuracy: 0.8627
# Epoch 16/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0300 - accuracy: 0.9951 - val_loss: 0.4763 - val_accuracy: 0.8725
# Epoch 17/50
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0231 - accuracy: 0.9926 - val_loss: 0.4720 - val_accuracy: 0.9118
# Epoch 18/50
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0615 - accuracy: 0.9754 - val_loss: 0.5327 - val_accuracy: 0.8725
# Epoch 19/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1012 - accuracy: 0.9681 - val_loss: 0.4504 - val_accuracy: 0.8824
# Epoch 20/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0639 - accuracy: 0.9828 - val_loss: 0.3354 - val_accuracy: 0.8922
# Epoch 21/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0275 - accuracy: 0.9902 - val_loss: 0.4098 - val_accuracy: 0.9020
# Epoch 22/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0230 - accuracy: 0.9951 - val_loss: 0.4622 - val_accuracy: 0.8824
# Epoch 23/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0253 - accuracy: 0.9877 - val_loss: 0.4663 - val_accuracy: 0.8922
# Epoch 24/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0200 - accuracy: 0.9926 - val_loss: 0.5123 - val_accuracy: 0.9118
# Epoch 25/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4856 - val_accuracy: 0.8824
# Epoch 26/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4288 - val_accuracy: 0.9118
# Epoch 27/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4946 - val_accuracy: 0.9020
# Epoch 28/50
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4474 - val_accuracy: 0.8922
# Epoch 29/50
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4561 - val_accuracy: 0.8922
# Epoch 30/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4699 - val_accuracy: 0.8922
# Epoch 31/50
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4796 - val_accuracy: 0.8922
# Epoch 32/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.8922
# Epoch 33/50
# 26/26 [==============================] - 0s 9ms/step - loss: 9.9738e-04 - accuracy: 1.0000 - val_loss: 0.4947 - val_accuracy: 0.8922
# Epoch 34/50
# 26/26 [==============================] - 0s 10ms/step - loss: 9.0800e-04 - accuracy: 1.0000 - val_loss: 0.4955 - val_accuracy: 0.8922
# Epoch 35/50
# 26/26 [==============================] - 0s 9ms/step - loss: 8.3491e-04 - accuracy: 1.0000 - val_loss: 0.5002 - val_accuracy: 0.8922
# Epoch 36/50
# 26/26 [==============================] - 0s 9ms/step - loss: 7.7849e-04 - accuracy: 1.0000 - val_loss: 0.5044 - val_accuracy: 0.8922
# Epoch 37/50
# 26/26 [==============================] - 0s 9ms/step - loss: 7.1891e-04 - accuracy: 1.0000 - val_loss: 0.5126 - val_accuracy: 0.8922
# Epoch 38/50
# 26/26 [==============================] - 0s 10ms/step - loss: 6.6836e-04 - accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8922
# Epoch 39/50
# 26/26 [==============================] - 0s 13ms/step - loss: 6.2787e-04 - accuracy: 1.0000 - val_loss: 0.5205 - val_accuracy: 0.8922
# Epoch 40/50
# 26/26 [==============================] - 0s 13ms/step - loss: 5.9190e-04 - accuracy: 1.0000 - val_loss: 0.5276 - val_accuracy: 0.8922
# Epoch 41/50
# 26/26 [==============================] - 0s 10ms/step - loss: 5.4708e-04 - accuracy: 1.0000 - val_loss: 0.5278 - val_accuracy: 0.8922
# Epoch 42/50
# 26/26 [==============================] - 0s 11ms/step - loss: 5.1556e-04 - accuracy: 1.0000 - val_loss: 0.5321 - val_accuracy: 0.8922
# Epoch 43/50
# 26/26 [==============================] - 0s 10ms/step - loss: 5.0069e-04 - accuracy: 1.0000 - val_loss: 0.5455 - val_accuracy: 0.8922
# Epoch 44/50
# 26/26 [==============================] - 0s 9ms/step - loss: 4.7095e-04 - accuracy: 1.0000 - val_loss: 0.5417 - val_accuracy: 0.8922
# Epoch 45/50
# 26/26 [==============================] - 0s 10ms/step - loss: 4.6273e-04 - accuracy: 1.0000 - val_loss: 0.5595 - val_accuracy: 0.8922
# Epoch 46/50
# 26/26 [==============================] - 0s 10ms/step - loss: 4.0216e-04 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.8922
# Epoch 47/50
# 26/26 [==============================] - 0s 9ms/step - loss: 3.8435e-04 - accuracy: 1.0000 - val_loss: 0.5534 - val_accuracy: 0.8922
# Epoch 48/50
# 26/26 [==============================] - 0s 9ms/step - loss: 3.7155e-04 - accuracy: 1.0000 - val_loss: 0.5615 - val_accuracy: 0.8922
# Epoch 49/50
# 26/26 [==============================] - 0s 10ms/step - loss: 3.5473e-04 - accuracy: 1.0000 - val_loss: 0.5591 - val_accuracy: 0.8922
# Epoch 50/50
# 26/26 [==============================] - 0s 12ms/step - loss: 3.3354e-04 - accuracy: 1.0000 - val_loss: 0.5641 - val_accuracy: 0.8922

# %%
ypred = fmodel.predict(xtest)
ypred = ypred > 0.5
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80        29
#            1       0.91      0.95      0.93        73
#
#     accuracy                           0.89       102
#    macro avg       0.88      0.85      0.86       102
# weighted avg       0.89      0.89      0.89       102

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True)
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %% [markdown]
# *Model performance improved from 79% to 92% accuracy*

# %%
history.history
# Out:
# {'loss': [0.6003718972206116,
#   0.5695242285728455,
#   0.5453474521636963,
#   0.5025642514228821,
#   0.4177898168563843,
#   0.32053717970848083,
#   0.24514169991016388,
#   0.18164090812206268,
#   0.13652773201465607,
#   0.12195870280265808,
#   0.12792342901229858,
#   0.0653112456202507,
#   0.03816213831305504,
#   0.08303393423557281,
#   0.07638699561357498,
#   0.029984425753355026,
#   0.023099832236766815,
#   0.06149526685476303,
#   0.10117669403553009,
#   0.0639326274394989,
#   0.02747936360538006,
#   0.02299896627664566,
#   0.025294899940490723,
#   0.01998615823686123,
#   0.00914688315242529,
#   0.004603973589837551,
#   0.0034429144579917192,
#   0.0026584509760141373,
#   0.0015815324150025845,
#   0.0013415785506367683,
#   0.0012043011374771595,
#   0.0010859002359211445,
#   0.0009973762789741158,
#   0.0009080009767785668,
#   0.0008349122363142669,
#   0.0007784902700223029,
#   0.0007189087336882949,
#   0.0006683618412353098,
#   0.0006278728833422065,
#   0.0005919018876738846,
#   0.0005470765754580498,
#   0.0005155640537850559,
#   0.0005006905412301421,
#   0.00047094718320295215,
#   0.0004627346934285015,
#   0.0004021575441583991,
#   0.0003843541780952364,
#   0.0003715455823112279,
#   0.00035473378375172615,
#   0.0003335394139867276],
#  'accuracy': [0.7321867346763611,
#   0.7321867346763611,
